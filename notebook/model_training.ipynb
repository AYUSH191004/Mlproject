# %%
import pandas as pd

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/sunnysavita10/Gemstone-Price-Prediction-End-to-End-Pipeline/main/artifacts/raw.csv")

# %%
df=df.drop(['id'],axis=1)

# %%
df.head(2)
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387

# %%
X=df   # 'X' it will be featured data

# %%
X.head(2)
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387

# %%
Y= df[["price"]] ## 'Y' will be target feature

# %%
Y.head(2)
# Out:
#    price
# 0  13619
# 1  13387

# %%
num_col=df.select_dtypes(exclude="object").columns
cat_col=df.select_dtypes(include="object").columns

# %%
num_col
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
cat_col
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
cut_cat=['Fair','Good','Very Good','Premium','Ideal']
clarity_cat=['IF','VVS1','VVS2','VS1','VS2','SI1','SI2','I1']
color_cat=['D','E','F','G','H','I','J']

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %% [markdown]
# PIPELINE:
# 1. IMPUTER
# 2. ENCODING
# 3. SCALING

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import  Pipeline
from sklearn.compose  import  ColumnTransformer

# %%
num_pip=Pipeline(
    steps=[
    ('imuter',SimpleImputer(strategy='median')),
    ('scaling',StandardScaler()),
    ]
)


cat_pip=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy="most_frequent")),
    ('encoding',OrdinalEncoder(categories=[cut_cat,color_cat,clarity_cat])),

    ]
)


preprocessor=ColumnTransformer(
        [
            ('numpipeline',num_pip,num_col),
            ('categoricalpipeline',cat_pip,cat_col)
        ]


)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train
# Out:
#         carat      cut color clarity  depth  table     x     y     z  price
# 168192   0.34    Ideal     I    VVS2   60.9   57.0  4.56  4.53  2.76    765
# 35202    0.90     Good     E     SI1   63.8   57.0  6.07  6.03  3.87   4763
# 41091    1.02  Premium     G     VS1   62.7   58.0  6.35  6.39  4.00   6139
# 31239    0.32  Premium     G     VS2   62.1   59.0  4.37  4.35  2.71    720
# 45722    0.35    Ideal     J    VVS2   61.1   56.0  4.53  4.57  2.78    774
# ...       ...      ...   ...     ...    ...    ...   ...   ...   ...    ...
# 66455    0.31    Ideal     E     SI1   61.8   56.0  4.31  4.35  2.68    544
# 46220    1.25    Ideal     G     SI2   62.0   56.0  6.88  6.95  4.28   5694
# 98804    1.00     Good     G     SI1   63.5   56.0  6.29  6.37  4.02   4563
# 48045    1.10    Ideal     G     VS1   59.9   60.0  6.68  6.77  4.01   6998
# 169765   0.91    Ideal     G     SI1   62.7   57.0  6.14  6.18  3.86   4922
#
# [135501 rows x 10 columns]

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())

# %%
X_test
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 70432    0.53    Premium     E     VS2   60.8   56.0  5.24  5.21  3.19   1607
# 64839    0.71  Very Good     H     SI1   62.9   57.0  5.67  5.69  3.56   2211
# 185316   0.30      Ideal     H      IF   62.1   57.0  4.27  4.29  2.66    764
# 84658    1.24    Premium     G     VS2   61.6   61.0  6.88  6.82  4.21   7655
# 31953    0.36    Premium     E     VS1   60.4   58.0  4.60  4.63  2.80    735
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 192694   1.26  Very Good     H     VS2   63.1   56.0  6.83  6.87  4.33   5785
# 133935   0.33      Ideal     F    VVS1   62.1   55.0  4.45  4.48  2.77    914
# 44763    0.70    Premium     J     VS2   58.2   60.0  5.83  5.80  3.38   2010
# 29856    0.41      Ideal     G     SI1   61.6   57.0  4.77  4.75  2.93    923
# 62426    2.00    Premium     J     VS2   61.0   60.0  8.09  7.97  4.92  14344
#
# [58072 rows x 10 columns]

# %%
X_test=pd.DataFrame(preprocessor.fit_transform(X_test),columns=preprocessor.get_feature_names_out())                                        ## using tranform  to overcome data leakage problem

# %%
X_train.drop(labels="numpipeline__price",axis=1)    ##DROP THE TARGET FEATURE
X_test.drop(labels="numpipeline__price",axis=1)
# Out:
#        numpipeline__carat  numpipeline__depth  numpipeline__table  \
# 0               -0.560473           -0.946668           -0.632686
# 1               -0.171673            0.990913           -0.111947
# 2               -1.057274            0.252787           -0.111947
# 3                0.973129           -0.208542            1.971009
# 4               -0.927674           -1.315731            0.408792
# ...                   ...                 ...                 ...
# 58067            1.016329            1.175444           -0.632686
# 58068           -0.992474            0.252787           -1.153426
# 58069           -0.193273           -3.345577            1.450270
# 58070           -0.819674           -0.208542           -0.111947
# 58071            2.614731           -0.762136            1.450270
#
#        numpipeline__x  numpipeline__y  numpipeline__z  \
# 0           -0.425330       -0.459668       -0.498885
# 1           -0.037825       -0.024281        0.040318
# 2           -1.299471       -1.294159       -1.271258
# 3            1.052598        1.000693        0.987567
# 4           -1.002083       -0.985760       -1.067235
# ...               ...             ...             ...
# 58067        1.007539        1.046046        1.162444
# 58068       -1.137259       -1.121819       -1.110954
# 58069        0.106363        0.075496       -0.221997
# 58070       -0.848883       -0.876913       -0.877785
# 58071        2.143021        2.043808        2.022254
#
#        categoricalpipeline__cut  categoricalpipeline__color  \
# 0                           3.0                         1.0
# 1                           2.0                         4.0
# 2                           4.0                         4.0
# 3                           3.0                         3.0
# 4                           3.0                         1.0
# ...                         ...                         ...
# 58067                       2.0                         4.0
# 58068                       4.0                         2.0
# 58069                       3.0                         6.0
# 58070                       4.0                         3.0
# 58071                       3.0                         6.0
#
#        categoricalpipeline__clarity
# 0                               4.0
# 1                               5.0
# 2                               0.0
# 3                               4.0
# 4                               3.0
# ...                             ...
# 58067                           4.0
# 58068                           1.0
# 58069                           4.0
# 58070                           5.0
# 58071                           4.0
#
# [58072 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_log_error

# %%
## Train multiple models
Models={
    'Linearregression':LinearRegression(),
    'lasso' : Lasso(),
    'ridge' : Ridge(),
    'ElasticNet': ElasticNet(),
  
 }

# %%
  
Trained_model_list=[Models]

# %%
Trained_model_list
# Out:
# [{'Linearregression': LinearRegression(),
#   'lasso': Lasso(),
#   'ridge': Ridge(),
#   'ElasticNet': ElasticNet()}]

# %%
Models_list=[]
r2_list=[]

# %%
list(Models)
# Out:
# ['Linearregression', 'lasso', 'ridge', 'ElasticNet']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_log_error, r2_score

Models_list = []
r2_list = []

for i in range(len(list(Models))):
    MODEL = list(Models.values())[i]
    MODEL.fit(X_train, Y_train)
    
    Y_pred_train = MODEL.predict(X_train)
    Y_pred_test = MODEL.predict(X_test)

    mae = mean_absolute_error(Y_test, Y_pred_test)
    msle = mean_squared_log_error(Y_test, Y_pred_test)
    r2 = r2_score(Y_test, Y_pred_test)

    print(list(Models.keys())[i])
    Models_list.append(list(Models.keys())[i])

    print("MODEL TRAINING PERFORMANCE:")
    print(f"MAE: {mae}, MSLE: {msle}, R2_score: {r2*100}")

    r2_list.append(r2)

# At this point, Models_list and r2_list will have the model names and corresponding R2 scores.


print("="*35)


print("/n")
# Out:
# Linearregression
# MODEL TRAINING PERFORMANCE:
# MAE: 5.519934640532064, MSLE: 3.9800176057033784e-05, R2_score: 99.9997895196216
# lasso
# MODEL TRAINING PERFORMANCE:
# MAE: 6.038936987164776, MSLE: 4.301387976466782e-05, R2_score: 99.99975059962463
# ridge
# MODEL TRAINING PERFORMANCE:
# MAE: 5.539665376901369, MSLE: 3.953671975896676e-05, R2_score: 99.99978849707882
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 14
#      11 Y_pred_test = MODEL.predict(X_test)
#      13 mae = mean_absolute_error(Y_test, Y_pred_test)
# ---> 14 msle = mean_squared_log_error(Y_test, Y_pred_test)
#      15 r2 = r2_score(Y_test, Y_pred_test)
#      17 print(list(Models.keys())[i])
#
# File h:\ml project\env\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File h:\ml project\env\lib\site-packages\sklearn\metrics\_regression.py:567, in mean_squared_log_error(y_true, y_pred, sample_weight, multioutput, squared)
#     564 check_consistent_length(y_true, y_pred, sample_weight)
#     566 if (y_true < 0).any() or (y_pred < 0).any():
# --> 567     raise ValueError(
#     568         "Mean Squared Logarithmic Error cannot be used when "
#     569         "targets contain negative values."
#     570     )
#     572 return mean_squared_error(
#     573     np.log1p(y_true),
#     574     np.log1p(y_pred),
#    (...)
#     577     squared=squared,
#     578 )
#
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
